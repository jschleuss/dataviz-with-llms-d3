# %% [markdown]
# ## Setup
#
# This section is for setting up the python environment.
#
# It loads a few python libraries we'll be using.
#
# You can just run it and move on!

# %%
# Pandas and NumPy settings for data analysis
import pandas as pd
import numpy as np

# Always show all dataframe columns
pd.set_option('display.max_columns', None)

# Some libraries for better displaying in Jupyter
from IPython.display import display, HTML

# TQDM for progress bars
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
import os
import openai
import dotenv
dotenv.load_dotenv()

openai.organization = None
openai.api_key = os.getenv("OPENAI_API_KEY")
# openai.Model.list() # see all openai models

# %% [markdown]
# ## Load Data
#
# In this section I show the ouptput of some data we grabbed from MediaCloud.

# %%
 # Load bill summaries for Maryland bills
stories = pd.read_csv('stories_df.csv')

# Display the stories
stories
# Out:
#                                                   title publication_date  \
# 0     Tom Sandoval invoked George Floyd when talking...       2024-03-01
# 1     Water levels plunge at California's biggest re...       2024-03-01
# 2                Why U.S. Troops Should Remain in Syria       2024-03-01
# 3     Winter storm warning issued for 8 states as ex...       2024-03-01
# 4     Woman lets fiancé help with wedding invitation...       2024-03-01
# ...                                                 ...              ...
# 9080  We found the best deals on any version of Appl...       2024-02-26
# 9081             Donald Trump accused of stealing music       2024-02-26
# 9082  Better sleep is yours with these top mattresse...       2024-02-26
# 9083  The 5 best spring cleaning deals on robot vacu...       2024-02-26
# 9084  Exclusive: Biden Admin Planted Operative in Fa...       2024-02-26
#
#               capture_time language         domain  \
# 0     2024-03-03T13:50:42Z       en    latimes.com
# 1     2024-03-02T21:06:48Z       en   newsweek.com
# 2     2024-03-02T22:53:20Z       en   newsweek.com
# 3     2024-03-02T08:31:19Z       en   newsweek.com
# 4     2024-03-02T06:48:27Z       en   newsweek.com
# ...                    ...      ...            ...
# 9080  2024-02-27T03:53:43Z       en    cbsnews.com
# 9081  2024-02-27T01:46:28Z       en   newsweek.com
# 9082  2024-02-27T04:58:13Z       en    cbsnews.com
# 9083  2024-02-27T06:13:41Z       en    cbsnews.com
# 9084  2024-02-27T02:36:28Z       en  breitbart.com
#
#                                                     url  \
# 0     https://www.latimes.com/entertainment-arts/tv/...
# 1     https://www.newsweek.com/water-levels-plunge-c...
# 2     https://www.newsweek.com/why-us-troops-should-...
# 3     https://www.newsweek.com/winter-storm-warning-...
# 4     https://www.newsweek.com/woman-fiance-help-wed...
# ...                                                 ...
# 9080  https://www.cbsnews.com/essentials/best-apple-...
# 9081  https://www.newsweek.com/donald-trump-accused-...
# 9082  https://www.cbsnews.com/essentials/best-mattre...
# 9083  https://www.cbsnews.com/essentials/best-robot-...
# 9084  https://www.breitbart.com/2024-election/2024/0...
#
#                                    original_capture_url  \
# 0     https://web.archive.org/web/20240303135042id_/...
# 1     https://web.archive.org/web/20240302210648id_/...
# 2     https://web.archive.org/web/20240302225320id_/...
# 3     https://web.archive.org/web/20240302083119id_/...
# 4     https://web.archive.org/web/20240302064827id_/...
# ...                                                 ...
# 9080  https://web.archive.org/web/20240227035343id_/...
# 9081  https://web.archive.org/web/20240227014628id_/...
# 9082  https://web.archive.org/web/20240227045813id_/...
# 9083  https://web.archive.org/web/20240227061341id_/...
# 9084  https://web.archive.org/web/20240227023628id_/...
#
#                                    archive_playback_url  \
# 0     https://web.archive.org/web/20240303135042/htt...
# 1     https://web.archive.org/web/20240302210648/htt...
# 2     https://web.archive.org/web/20240302225320/htt...
# 3     https://web.archive.org/web/20240302083119/htt...
# 4     https://web.archive.org/web/20240302064827/htt...
# ...                                                 ...
# 9080  https://web.archive.org/web/20240227035343/htt...
# 9081  https://web.archive.org/web/20240227014628/htt...
# 9082  https://web.archive.org/web/20240227045813/htt...
# 9083  https://web.archive.org/web/20240227061341/htt...
# 9084  https://web.archive.org/web/20240227023628/htt...
#
#                                             article_url  \
# 0     https://wayback-api.archive.org/colsearch/v1/m...
# 1     https://wayback-api.archive.org/colsearch/v1/m...
# 2     https://wayback-api.archive.org/colsearch/v1/m...
# 3     https://wayback-api.archive.org/colsearch/v1/m...
# 4     https://wayback-api.archive.org/colsearch/v1/m...
# ...                                                 ...
# 9080  https://wayback-api.archive.org/colsearch/v1/m...
# 9081  https://wayback-api.archive.org/colsearch/v1/m...
# 9082  https://wayback-api.archive.org/colsearch/v1/m...
# 9083  https://wayback-api.archive.org/colsearch/v1/m...
# 9084  https://wayback-api.archive.org/colsearch/v1/m...
#
#                                                 snippet
# 0     Tom Sandoval invoked George Floyd when talking...
# 1     Water levels have plunged by nearly 7 feet at ...
# 2     Few people today recognize the name of Alois B...
# 3     Winter storm warnings are in place for parts o...
# 4     In the world of wedding planning, there are bo...
# ...                                                 ...
# 9080  We found the best deals on any version of Appl...
# 9081  Donald Trump has once again been accused of st...
# 9082  Better sleep is yours with these top mattresse...
# 9083  The 5 best spring cleaning deals on robot vacu...
# 9084  The Biden administration planted a Democrat op...
#
# [9085 rows x 10 columns]

# %% [markdown]
# # Keywords
#
# This section extracts some keywords from the bills using a library called `yake` (Yet Another Keyword Extractor)
#
# It also uses `pandarallel` to parallelize this process and get it done faster!

# %%
from yake import KeywordExtractor
from pandarallel import pandarallel

# Define a function to extract ketwords from a text
kw_extractor = KeywordExtractor()
def get_keywords(text):
    keywords = kw_extractor.extract_keywords(text)
    return [x for x,y in keywords]

# Run the function in parallel to speed things up
pandarallel.initialize(progress_bar=True)
stories['keywords'] = stories['snippet'].parallel_apply(get_keywords)

# display the stories with the keywords attatched
stories
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1136), Label(value='0 / 1136'))), …
#                                                   title publication_date  \
# 0     Tom Sandoval invoked George Floyd when talking...       2024-03-01
# 1     Water levels plunge at California's biggest re...       2024-03-01
# 2                Why U.S. Troops Should Remain in Syria       2024-03-01
# 3     Winter storm warning issued for 8 states as ex...       2024-03-01
# 4     Woman lets fiancé help with wedding invitation...       2024-03-01
# ...                                                 ...              ...
# 9080  We found the best deals on any version of Appl...       2024-02-26
# 9081             Donald Trump accused of stealing music       2024-02-26
# 9082  Better sleep is yours with these top mattresse...       2024-02-26
# 9083  The 5 best spring cleaning deals on robot vacu...       2024-02-26
# 9084  Exclusive: Biden Admin Planted Operative in Fa...       2024-02-26
#
#               capture_time language         domain  \
# 0     2024-03-03T13:50:42Z       en    latimes.com
# 1     2024-03-02T21:06:48Z       en   newsweek.com
# 2     2024-03-02T22:53:20Z       en   newsweek.com
# 3     2024-03-02T08:31:19Z       en   newsweek.com
# 4     2024-03-02T06:48:27Z       en   newsweek.com
# ...                    ...      ...            ...
# 9080  2024-02-27T03:53:43Z       en    cbsnews.com
# 9081  2024-02-27T01:46:28Z       en   newsweek.com
# 9082  2024-02-27T04:58:13Z       en    cbsnews.com
# 9083  2024-02-27T06:13:41Z       en    cbsnews.com
# 9084  2024-02-27T02:36:28Z       en  breitbart.com
#
#                                                     url  \
# 0     https://www.latimes.com/entertainment-arts/tv/...
# 1     https://www.newsweek.com/water-levels-plunge-c...
# 2     https://www.newsweek.com/why-us-troops-should-...
# 3     https://www.newsweek.com/winter-storm-warning-...
# 4     https://www.newsweek.com/woman-fiance-help-wed...
# ...                                                 ...
# 9080  https://www.cbsnews.com/essentials/best-apple-...
# 9081  https://www.newsweek.com/donald-trump-accused-...
# 9082  https://www.cbsnews.com/essentials/best-mattre...
# 9083  https://www.cbsnews.com/essentials/best-robot-...
# 9084  https://www.breitbart.com/2024-election/2024/0...
#
#                                    original_capture_url  \
# 0     https://web.archive.org/web/20240303135042id_/...
# 1     https://web.archive.org/web/20240302210648id_/...
# 2     https://web.archive.org/web/20240302225320id_/...
# 3     https://web.archive.org/web/20240302083119id_/...
# 4     https://web.archive.org/web/20240302064827id_/...
# ...                                                 ...
# 9080  https://web.archive.org/web/20240227035343id_/...
# 9081  https://web.archive.org/web/20240227014628id_/...
# 9082  https://web.archive.org/web/20240227045813id_/...
# 9083  https://web.archive.org/web/20240227061341id_/...
# 9084  https://web.archive.org/web/20240227023628id_/...
#
#                                    archive_playback_url  \
# 0     https://web.archive.org/web/20240303135042/htt...
# 1     https://web.archive.org/web/20240302210648/htt...
# 2     https://web.archive.org/web/20240302225320/htt...
# 3     https://web.archive.org/web/20240302083119/htt...
# 4     https://web.archive.org/web/20240302064827/htt...
# ...                                                 ...
# 9080  https://web.archive.org/web/20240227035343/htt...
# 9081  https://web.archive.org/web/20240227014628/htt...
# 9082  https://web.archive.org/web/20240227045813/htt...
# 9083  https://web.archive.org/web/20240227061341/htt...
# 9084  https://web.archive.org/web/20240227023628/htt...
#
#                                             article_url  \
# 0     https://wayback-api.archive.org/colsearch/v1/m...
# 1     https://wayback-api.archive.org/colsearch/v1/m...
# 2     https://wayback-api.archive.org/colsearch/v1/m...
# 3     https://wayback-api.archive.org/colsearch/v1/m...
# 4     https://wayback-api.archive.org/colsearch/v1/m...
# ...                                                 ...
# 9080  https://wayback-api.archive.org/colsearch/v1/m...
# 9081  https://wayback-api.archive.org/colsearch/v1/m...
# 9082  https://wayback-api.archive.org/colsearch/v1/m...
# 9083  https://wayback-api.archive.org/colsearch/v1/m...
# 9084  https://wayback-api.archive.org/colsearch/v1/m...
#
#                                                 snippet  \
# 0     Tom Sandoval invoked George Floyd when talking...
# 1     Water levels have plunged by nearly 7 feet at ...
# 2     Few people today recognize the name of Alois B...
# 3     Winter storm warnings are in place for parts o...
# 4     In the world of wedding planning, there are bo...
# ...                                                 ...
# 9080  We found the best deals on any version of Appl...
# 9081  Donald Trump has once again been accused of st...
# 9082  Better sleep is yours with these top mattresse...
# 9083  The 5 best spring cleaning deals on robot vacu...
# 9084  The Biden administration planted a Democrat op...
#
#                                                keywords
# 0     [Sandoval invoked George, invoked George Floyd...
# 1     [Lake Shasta, Lake Shasta water, Lake, Shasta,...
# 2     [Alois Brunner, Syria, official Adolph Eichman...
# 3     [National Weather Service, snow, Sierra Nevada...
# 4     [wedding planning, wedding, Brooke, Brooke Pie...
# ...                                                 ...
# 9080  [Apple AirPods, Apple, Apple AirPods Pro, AirP...
# 9081  [Trump, White House leader, Donald Trump, News...
# 9082  [mattress, sleep, sleepers, mattresses, memory...
# 9083  [robot vacuum, robot, vacuum, robot vacuum dea...
# 9084  [County District Attorney, District Attorney, ...
#
# [9085 rows x 11 columns]

# %% [markdown]
# ## Remove documents that are too big
#
# OpenAI models have a context window of ~8000 tokens.
#
# https://platform.openai.com/docs/guides/embeddings/embedding-models
#
# So we'll remove any documents that are longer than that for now.
#
# We can use `tiktoken` to [count the tokens](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb) in each document.

# %%
# Import modules
import tiktoken
from openai import OpenAI
client = OpenAI()

# Set embedding model parameters
embedding_model = "text-embedding-3-small" # this is the model we will use to make embeddings
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# Get the encoding for the specified model
encoding = tiktoken.get_encoding(embedding_encoding)

# Make a new column with the combined title and summary
stories["combined"] = (
    "Title: " + stories.title.str.strip() + "; Content: " + stories.snippet.str.strip()
)

# Make a new column with the number of tokens in the combined title and summary
stories["n_tokens"] = stories.combined.apply(lambda x: len(encoding.encode(x)))

# Sort by that column
stories = stories.sort_values(by='n_tokens', ascending=False)

# Display the stories
stories
# Out:
#                                                   title publication_date  \
# 1504  Gemini’s Culture War, Kara Swisher Burns Us an...       2024-03-01
# 2287  A look at the politics behind Trump and Biden’...       2024-02-29
# 5785  The Tip Sheet: How Biden Can Flip the Script A...       2024-02-27
# 3275  49 Items That'll Get Name Brand Results At A L...       2024-02-29
# 2354  “Because of Joe Biden’s policies — and the mor...       2024-02-29
# ...                                                 ...              ...
# 3009                         Lancaster Roasting Company       2024-02-29
# 3101  Florida grandmother accused of kidnapping sent...       2024-02-29
# 5356    Lightning bolt flashes over downtown Pittsburgh       2024-02-28
# 6656  Learning more about Pittsburgh's Citizen Scien...       2024-02-27
# 3040  Construction update on Pittsburgh Internationa...       2024-02-29
#
#               capture_time language        domain  \
# 1504  2024-03-04T03:17:00Z       en   nytimes.com
# 2287  2024-03-02T05:16:54Z       en   nytimes.com
# 5785  2024-03-05T04:31:24Z       en   nytimes.com
# 3275  2024-03-03T02:37:39Z       en  buzzfeed.com
# 2354  2024-03-02T15:27:17Z       en   nytimes.com
# ...                    ...      ...           ...
# 3009  2024-03-03T00:55:05Z       en   cbsnews.com
# 3101  2024-03-03T08:11:35Z       en   cbsnews.com
# 5356  2024-03-01T17:48:09Z       en   cbsnews.com
# 6656  2024-02-29T05:29:51Z       en   cbsnews.com
# 3040  2024-03-03T15:04:58Z       en   cbsnews.com
#
#                                                     url  \
# 1504  https://www.nytimes.com/2024/03/01/podcasts/ha...
# 2287  https://www.nytimes.com/live/2024/02/29/us/bid...
# 5785  https://www.nytimes.com/live/2024/02/27/opinio...
# 3275  https://www.buzzfeed.com/nataliebrown/products...
# 2354  https://www.nytimes.com/live/2024/02/29/us/bid...
# ...                                                 ...
# 3009  https://www.cbsnews.com/losangeles/video/lanca...
# 3101  https://www.cbsnews.com/miami/video/florida-gr...
# 5356  https://www.cbsnews.com/pittsburgh/video/light...
# 6656  https://www.cbsnews.com/pittsburgh/video/learn...
# 3040  https://www.cbsnews.com/pittsburgh/video/const...
#
#                                    original_capture_url  \
# 1504  https://web.archive.org/web/20240304031700id_/...
# 2287  https://web.archive.org/web/20240302051654id_/...
# 5785  https://web.archive.org/web/20240305043124id_/...
# 3275  https://web.archive.org/web/20240303023739id_/...
# 2354  https://web.archive.org/web/20240302152717id_/...
# ...                                                 ...
# 3009  https://web.archive.org/web/20240303005505id_/...
# 3101  https://web.archive.org/web/20240303081135id_/...
# 5356  https://web.archive.org/web/20240301174809id_/...
# 6656  https://web.archive.org/web/20240229052951id_/...
# 3040  https://web.archive.org/web/20240303150458id_/...
#
#                                    archive_playback_url  \
# 1504  https://web.archive.org/web/20240304031700/htt...
# 2287  https://web.archive.org/web/20240302051654/htt...
# 5785  https://web.archive.org/web/20240305043124/htt...
# 3275  https://web.archive.org/web/20240303023739/htt...
# 2354  https://web.archive.org/web/20240302152717/htt...
# ...                                                 ...
# 3009  https://web.archive.org/web/20240303005505/htt...
# 3101  https://web.archive.org/web/20240303081135/htt...
# 5356  https://web.archive.org/web/20240301174809/htt...
# 6656  https://web.archive.org/web/20240229052951/htt...
# 3040  https://web.archive.org/web/20240303150458/htt...
#
#                                             article_url  \
# 1504  https://wayback-api.archive.org/colsearch/v1/m...
# 2287  https://wayback-api.archive.org/colsearch/v1/m...
# 5785  https://wayback-api.archive.org/colsearch/v1/m...
# 3275  https://wayback-api.archive.org/colsearch/v1/m...
# 2354  https://wayback-api.archive.org/colsearch/v1/m...
# ...                                                 ...
# 3009  https://wayback-api.archive.org/colsearch/v1/m...
# 3101  https://wayback-api.archive.org/colsearch/v1/m...
# 5356  https://wayback-api.archive.org/colsearch/v1/m...
# 6656  https://wayback-api.archive.org/colsearch/v1/m...
# 3040  https://wayback-api.archive.org/colsearch/v1/m...
#
#                                                 snippet  \
# 1504  transcript\nGemini’s Culture War, Kara Swisher...
# 2287  In Dual Border Visits, Biden and Trump Try to ...
# 5785  The PointConversations and insights about the ...
# 3275  1. Neutrogena Norwegian Formula Hand Cream, wh...
# 2354  In Dual Border Visits, Biden and Trump Try to ...
# ...                                                 ...
# 3009  Lancaster Roasting Company | People Making A D...
# 3101  Florida grandmother accused of kidnapping sent...
# 5356  Lightning bolt flashes over downtown Pittsburg...
# 6656  Learning more about Pittsburgh's Citizen Scien...
# 3040  Construction update on Pittsburgh Internationa...
#
#                                                keywords  \
# 1504  [kevin roose, casey newton, Kara Swisher, Kevi...
# 2287  [President Biden, Biden, Eagle Pass, Trump, Bo...
# 5785  [Trump, Donald Trump, n’t, Biden, President Bi...
# 3275  [Promising reviews, Amazon, Promising, love, r...
# 2354  [President Biden, Eagle Pass, Biden, Border, T...
# ...                                                 ...
# 3009  [Lancaster Roasting Company, Roasting Company,...
# 3101  [Florida grandmother accused, Florida grandmot...
# 5356  [downtown Pittsburgh, Pittsburgh, Tower Cam ca...
# 6656  [Citizen Science Lab, Pittsburgh Citizen Scien...
# 3040  [Pittsburgh International Airport, Internation...
#
#                                                combined  n_tokens
# 1504  Title: Gemini’s Culture War, Kara Swisher Burn...     23245
# 2287  Title: A look at the politics behind Trump and...     14287
# 5785  Title: The Tip Sheet: How Biden Can Flip the S...     13607
# 3275  Title: 49 Items That'll Get Name Brand Results...     13170
# 2354  Title: “Because of Joe Biden’s policies — and ...     13079
# ...                                                 ...       ...
# 3009  Title: Lancaster Roasting Company; Content: La...        58
# 3101  Title: Florida grandmother accused of kidnappi...        58
# 5356  Title: Lightning bolt flashes over downtown Pi...        57
# 6656  Title: Learning more about Pittsburgh's Citize...        56
# 3040  Title: Construction update on Pittsburgh Inter...        56
#
# [9085 rows x 13 columns]

# %%
# Grab the rows where the text is too big for the context window of the mmodel (>8000 tokens)
too_long = stories.query("n_tokens > @max_tokens") 

# Print how many will be removed
print(f"Removing {len(too_long)} stories that are too long")

# Display the removed stories here in this cell so we can see what we're losing
display(too_long)  

# Remove the rows where the text is too big for the context window of the model
stories = stories.query("n_tokens <= @max_tokens")
# Out:
# Removing 43 stories that are too long
#                                                   title publication_date  \
# 1504  Gemini’s Culture War, Kara Swisher Burns Us an...       2024-03-01
# 2287  A look at the politics behind Trump and Biden’...       2024-02-29
# 5785  The Tip Sheet: How Biden Can Flip the Script A...       2024-02-27
# 3275  49 Items That'll Get Name Brand Results At A L...       2024-02-29
# 2354  “Because of Joe Biden’s policies — and the mor...       2024-02-29
# 2832  “Now the United States is being overrun by the...       2024-02-29
# 2838  ‘We built 571 miles of border wall, much more ...       2024-02-29
# 3278               2024 Netflix TV Shows You Must Watch       2024-02-29
# 2327  An uptick of arrivals in Brownsville reinforce...       2024-02-29
# 2834  Visiting the U.S. border has become a potent f...       2024-02-29
# 2810  Nikki Haley blasts Biden and Trump for ‘photo ...       2024-02-29
# 2829  Immigration and the southern border have been ...       2024-02-29
# 2845  Unauthorized border crossings dipped in Januar...       2024-02-29
# 2301  Biden takes an opportunity to shift from defen...       2024-02-29
# 2361  Backlogs at immigration courts highlight the d...       2024-02-29
# 2307  Eagle Pass has been at the epicenter of the mi...       2024-02-29
# 2306  Brownsville residents say their city does not ...       2024-02-29
# 2837     What is Biden thinking of doing at the border?       2024-02-29
# 5772  This TikTok Series May Be the ‘Beowulf’ of Our...       2024-02-27
# 5784  Readers Respond: Will Reproductive Rights Unit...       2024-02-27
# 5767  Every Rose at Navalny’s Funeral Was a Rebuke t...       2024-02-27
# 5763  In Gaza, Desperate Palestinians are Killed Whi...       2024-02-27
# 5787  Biden Can Do Better Than Airdropping Food to Gaza       2024-02-27
# 5764  Support Is Growing for a Global Tax on Billion...       2024-02-27
# 5770  The Supreme Court Gives Trump Just What He Wanted       2024-02-27
# 5768  The Unspoken Challenge to Diversifying Publishing       2024-02-27
# 8646  https://wayback-api.archive.org/colsearch/v1/m...
# 5734  https://wayback-api.archive.org/colsearch/v1/m...
# 5782  https://wayback-api.archive.org/colsearch/v1/m...
#
#                                                 snippet  \
# 1504  transcript\nGemini’s Culture War, Kara Swisher...
# 2287  In Dual Border Visits, Biden and Trump Try to ...
# 5785  The PointConversations and insights about the ...
# 3275  1. Neutrogena Norwegian Formula Hand Cream, wh...
# 2354  In Dual Border Visits, Biden and Trump Try to ...
# 2832  In Dual Border Visits, Biden and Trump Try to ...
# 2838  In Dual Border Visits, Biden and Trump Try to ...
# 3278  Trending badgeTrendingTV and MoviesÂ·Posted 5 ...
# 2327  In Dual Border Visits, Biden and Trump Try to ...
# 2834  In Dual Border Visits, Biden and Trump Try to ...
# 2810  In Dual Border Visits, Biden and Trump Try to ...
# 2829  In Dual Border Visits, Biden and Trump Try to ...
# 2845  In Dual Border Visits, Biden and Trump Try to ...
# 2301  In Dual Border Visits, Biden and Trump Try to ...
# 2361  In Dual Border Visits, Biden and Trump Try to ...
# 2307  In Dual Border Visits, Biden and Trump Try to ...
# 2306  In Dual Border Visits, Biden and Trump Try to ...
# 2837  In Dual Border Visits, Biden and Trump Try to ...
# 5772  The PointConversations and insights about the ...
# 5784  The PointConversations and insights about the ...
# 5767  The PointConversations and insights about the ...
# 5763  The PointConversations and insights about the ...
# 5787  The PointConversations and insights about the ...
# 5764  The PointConversations and insights about the ...
# 5770  The PointConversations and insights about the ...
# 5768  The PointConversations and insights about the ...
# 5771  The PointConversations and insights about the ...
# 5775  The PointConversations and insights about the ...
# 5765  The PointConversations and insights about the ...
# 5769  The PointConversations and insights about the ...
# 5779  Michigan Primary: Biden Confronts Protest Vote...
# 2543  transcript\nMAGA Thinks the Game Is Rigged. Wi...
# 1295  1. A portable safeÂ you can secure to a beach ...
# 5778  The PointConversations and insights about the ...
# 5786  The PointConversations and insights about the ...
# 5776  The PointConversations and insights about the ...
# 5766  The PointConversations and insights about the ...
# 1490  transcript\nThe Pro-Life Movement Had a Plan P...
# 8645  Supreme Court Seems Open to Tech Companies’ Ch...
# 8647  Supreme Court Seems Open to Tech Companies’ Ch...
# 8646  Supreme Court Seems Open to Tech Companies’ Ch...
# 5734  Michigan Primary Live Updates: Biden Confronts...
# 5782  Michigan Primary Live Updates: Biden Confronts...
#
#                                                keywords  \
# 1504  [kevin roose, casey newton, Kara Swisher, Kevi...
# 2287  [President Biden, Biden, Eagle Pass, Trump, Bo...
# 5785  [Trump, Donald Trump, n’t, Biden, President Bi...
# 3275  [Promising reviews, Amazon, Promising, love, r...
# 2354  [President Biden, Eagle Pass, Biden, Border, T...
# 2832  [President Biden, Eagle Pass, Biden, Border, T...
# 2838  [President Biden, Eagle Pass, Biden, Border, T...
# 3278  [Netflix revealed, Netflix, Courtesy Everett C...
# 2327  [President Biden, Eagle Pass, Biden, Border, T...
# 2834  [President Biden, Eagle Pass, Biden, Border, T...
# 2810  [President Biden, Eagle Pass, Biden, Border, T...
# 2829  [President Biden, Eagle Pass, Biden, Border, T...
# 2845  [President Biden, Eagle Pass, Biden, Border, T...
# 2301  [President Biden, Eagle Pass, Biden, Border, T...
# 2361  [President Biden, Eagle Pass, Biden, Border, T...
# 2307  [President Biden, Eagle Pass, Biden, Border, T...
# 2306  [President Biden, Eagle Pass, Biden, Border, T...
# 2837  [President Biden, Eagle Pass, Biden, Border, T...
# 5772  [n’t, Trump, President Biden, Gaza, Biden, Don...
# 
# 1295  Title: Boost Your Vacation Mood with These 44 ...     10545
# 5778  Title: No Room for Dictators at the Conductor’...     10137
# 5786  Title: Biden Should Be Worried About the Prote...      9679
# 5776  Title: A Moment of Trumpenfreude; Content: The...      9675
# 5766  Title: McConnell’s Iron Grip on Power Is Comin...      9199
# 1490  Title: The Pro-Life Movement Had a Plan Post-R...      8952
# 8645  Title: What does this case have to do Big Tech...      8549
# 8647  Title: Social media platforms decide what does...      8547
# 8646  Title: This is what’s at stake in Monday’s arg...      8546
# 5734  Title: The primary starts a consequential week...      8282
# 5782  Title: Initial results may favor Biden, but do...      8232

# %% [markdown]
# ## Embeddings
#
# Now we take the "combined" column, which contains the

# %%
from openai import OpenAI
client = OpenAI()

def get_embeddings(texts, model="text-embedding-3-small"):
    # Replace newlines in each text and ensure it's a list of texts
    texts = [text.replace("\n", " ") for text in texts]
    # OpenAI's embeddings.create can process multiple inputs as a list
    response = client.embeddings.create(input=texts, model=model)
    # Extract embeddings from the response
    embeddings = [item.embedding for item in response.data]
    return embeddings

# Function to process DataFrame in batches and return a list of embeddings
def process_in_batches(df, column_name, batch_size=10):
    # Break the DataFrame into batches of size `batch_size`
    batches = [df[column_name].iloc[i:i + batch_size] for i in range(0, len(df), batch_size)]
    # Process each batch and collect embeddings
    all_embeddings = []
    for batch in tqdm(batches, desc="Processing batches"):
        batch_embeddings = get_embeddings(batch.tolist())
        all_embeddings.extend(batch_embeddings)
    return all_embeddings

# Example usage
batch_size = 100  # Adjust based on your preference and rate limits
stories['embedding'] = process_in_batches(stories, 'combined', batch_size=batch_size)
# Out:
# Processing batches:   0%|          | 0/91 [00:00<?, ?it/s]
# /var/folders/k2/wlk_zlxn02sb9f62n1gwmpw00000gn/T/ipykernel_57237/642459923.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stories['embedding'] = process_in_batches(stories, 'combined', batch_size=batch_size)

# %%
# drop combined column since those were only for the purposes of making the embeddings
stories = stories.drop(columns=['combined', 'n_tokens'])

# %% [markdown]
# ## Dimensionality Reduction (t-SNE)
#
# The embedding is a vector in 1536 dimensions. Viewing data in that many dimensions would break your brain. 🤯
#
# Our brains can only handle 2 or 3 dimensions at a time. We'll use t-SNE to reduce the number of dimensions, flattening the multi-dimensional space into 2 dimensions.
#
# > Here are some things to keep in mind about t-SNE if you use it in the future. You may have to tweak some parameters to fit the needs of your data.
# >
# > Blog Post: [How to Use t-SNE Effectively](https://distill.pub/2016/misread-tsne/)

# %%
# find the one where bill.embedding is nan
stories[stories.embedding.isna()]
# Out:
# Empty DataFrame
# Columns: [title, publication_date, capture_time, language, domain, url, original_capture_url, archive_playback_url, article_url, snippet, keywords, embedding]
# Index: []

# %%
# remove where embedding is na 
stories = stories.dropna(subset=['embedding'])

# %%
from sklearn.manifold import TSNE
import numpy as np


# Convert to a list of lists of floats
matrix = np.array(stories.embedding.to_list())

# Create a t-SNE model and transform the data
tsne = TSNE(n_components=2, perplexity=30, random_state=42, init='random', learning_rate=400)
vis_dims = tsne.fit_transform(matrix)

# add to dataframe and write to csv
stories = stories\
    .assign(
        x = vis_dims[:,0], 
        y = vis_dims[:,1])

# %%
# Write the data to a CSV file
# stories.to_csv('../stories-with-embeddings.csv', index=False)
stories.drop(columns=['snippet', 'archive_playback_url', 'original_capture_url', 'embedding']).to_csv('../stories-no-snippet.csv', index=False)

# Display the bills
stories.head()
# Out:
#                                                   title publication_date  \
# 2095          Uncovering the higher truth of Jay Shetty       2024-02-29
# 5783  Biden will meet next month with the Teamsters ...       2024-02-27
# 4381                  Three Powerful Lessons About Love       2024-02-28
# 4742          22 Creepy Real-Life Stories February 2024       2024-02-28
# 8644  On the eve of the Michigan primary, a determin...       2024-02-26
#
#               capture_time language           domain  \
# 2095  2024-03-01T06:09:03Z       en  theguardian.com
# 5783  2024-02-28T02:38:34Z       en      nytimes.com
# 4381  2024-03-01T21:54:04Z       en      nytimes.com
# 4742  2024-03-01T09:53:11Z       en     buzzfeed.com
# 8644  2024-02-27T11:09:37Z       en      nytimes.com
#
#                                                     url  \
# 2095  https://www.theguardian.com/lifeandstyle/ng-in...
# 5783  https://www.nytimes.com/live/2024/02/27/us/tru...
# 4381  https://www.nytimes.com/2024/02/28/podcasts/mo...
# 4742  https://www.buzzfeed.com/angelicaamartinez/cre...
# 8644  https://www.nytimes.com/live/2024/02/26/us/tru...
#
#                                    original_capture_url  \
# 2095  https://web.archive.org/web/20240301060903id_/...
# 5783  https://web.archive.org/web/20240228023834id_/...
# 4381  https://web.archive.org/web/20240301215404id_/...
# 4742  https://web.archive.org/web/20240301095311id_/...
# 8644  https://web.archive.org/web/20240227110937id_/...
#
#                                    archive_playback_url  \
# 2095  https://web.archive.org/web/20240301060903/htt...
# 5783  https://web.archive.org/web/20240228023834/htt...
# 4381  https://web.archive.org/web/20240301215404/htt...
# 4742  https://web.archive.org/web/20240301095311/htt...
# 8644  https://web.archive.org/web/20240227110937/htt...
#
#                                             article_url  \
# 2095  https://wayback-api.archive.org/colsearch/v1/m...
# 5783  https://wayback-api.archive.org/colsearch/v1/m...
# 4381  https://wayback-api.archive.org/colsearch/v1/m...
# 4742  https://wayback-api.archive.org/colsearch/v1/m...
# 8644  https://wayback-api.archive.org/colsearch/v1/m...
#
#                                                 snippet  \
# 2095  On 20 August 2022, Jennifer Lopez and Ben Affl...
# 5783  Michigan Primary Live Updates: Biden Confronts...
# 4381  transcript\nThree Powerful Lessons About Love\...
# 4742  Every month, I ask BuzzFeed readers like you t...
# 8644  Election Updates: Trump and Biden will both vi...
#
#                                                keywords  \
# 2095  [Jay Shetty Certification, Shetty Certificatio...
# 5783  [Donald Trump, President Biden, Trump, Biden, ...
# 4381  [Daniel Jones, Modern Love, anna martin, Love,...
# 4742  [back, room, night, looked, house, phone, âAno...
# 8644  [Trump, Donald Trump, President Biden, Biden, ...
#
#                                               embedding          x          y
# 2095  [-0.006095091812312603, 0.0003404601593501866,... -24.708408 -41.372944
# 5783  [0.016431955620646477, 0.012380499392747879, 0... -72.246902  22.965057
# 4381  [0.0265309140086174, 0.016592005267739296, -0....  -8.077727 -35.600754
# 4742  [0.007826545275747776, 4.250243728165515e-05, ...   0.783140 -31.468397
# 8644  [0.03690981864929199, -0.0016414514975622296, ... -71.333710  23.542429
